# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Pdata =[
  {
    "YP": 0,
    "title": "청년 취창업 교육프로그램 운영",
    "R-number": "R2023060213129",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023060213129",
      "main_title": "청년 취창업 교육프로그램 운영",
      "short_description": "남양주시 청년층 대상 수요 및 트랜드 맞춤형 단기 실전 교육 진행",
      "summary": {
        "정책 번호": "R2023060213129",
        "정책 분야": "일자리분야",
        "지원 내용": "교육 프로그램 운영",
        "사업 운영 기간": "2023.01.01. ~ 2023.12.31.",
        "사업 신청 기간": "미정",
        "지원 규모(명)": "100명",
        "비고": "6~12월 중(예정)"
      },
      "qualification": {
        "연령": "만 19세 ~ 39세",
        "거주지 및 소득": "남양주시 거주, 소재 학교 또는 직장, 소재 사업자등록된 만39세 이하 청년",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "제한없음",
        "특화 분야": "제한없음",
        "추가 단서 사항": "-",
        "참여 제한 대상": "만19~39세 청년으로 제한 / 관내 거주,학교직장,사업자등록된 자로 제한"
      },
      "methods": {
        "신청 절차": "방문 및 온라인 접수",
        "심사 및 발표": "개별통지",
        "신청 사이트": "남양주시청 홈페이지(예정)",
        "제출 서류": "신청서, 남양주시 소재 증빙자료 등"
      },
      "etc": {
        "기타 유익 정보": "-",
        "주관 기관": "남양주시 문화교육국 청년정책과",
        "운영 기관": "주관기관과 동일",
        "사업관련 참고 사이트 1": "",
        "사업관련 참고 사이트 2": "",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 1,
    "title": "청년 취·창업 아카데미 운영",
    "R-number": "R2023050912468",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023050912468",
      "main_title": "청년 취·창업 아카데미 운영",
      "short_description": "청년창업관련 교육 및 취업준비자 대상 소그룹 현직자 집중 멘토링 제공",
      "summary": {
        "정책 번호": "R2023050912468",
        "정책 분야": "교육분야",
        "지원 내용": "창업기업가정신 함양, 청년창업관련 교육 및 취업자 소그룹 현직자 집중 멘토링 제공",
        "사업 운영 기간": "2023.01.01.~2023.12.31.",
        "사업 신청 기간": "2023년 04월 01일 ~ 2023년 12월 31일",
        "지원 규모(명)": "30명",
        "비고": "2023.4.~12."
      },
      "qualification": {
        "연령": "만 19세 ~ 39세",
        "거주지 및 소득": "만 19세~39세 미취업 청년",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "제한없음",
        "특화 분야": "제한없음",
        "추가 단서 사항": "-",
        "참여 제한 대상": "-"
      },
      "methods": {
        "신청 절차": "-",
        "심사 및 발표": "-",
        "신청 사이트": "프로그램별 상이",
        "제출 서류": "-"
      },
      "etc": {
        "기타 유익 정보": "-",
        "주관 기관": "성북구청 일자리정책과",
        "운영 기관": "-",
        "사업관련 참고 사이트 1": "",
        "사업관련 참고 사이트 2": "https://www.sb.go.kr/main/mainPage.do",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 2,
    "title": "이노베이션 아카데미",
    "R-number": "R2023031001935",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023031001935",
      "main_title": "이노베이션 아카데미",
      "short_description": "우수 SW 인재 육성을 위한 프로젝트 혁신 프로그램 지원",
      "summary": {
        "정책 번호": "R2023031001935",
        "정책 분야": "교육분야",
        "지원 내용": "(지원내용) 2년 비학위 과정의 교육(교육비 없음) 및 교육 지원금 제공\n- IT환경 지원 (데스크탑(아이맥) 775대 및 교육환경 구축)\n- 42서울 교육지원금: 교육과정 중(최대 2년) 월 최대 세전 100만원\n- 멘토링: 소프트웨어개발, 컨설팅 등 최고전문가(멘토단)의 멘토링 제공\n- 교육 및 개발공간: 24시간 개방형 교육생 학습공간 제공\n- 기업, 커뮤니티와 협력 프로젝트 기회 제공\n- 기타 42서울 교육생 베네핏 프로그램\n- (전달체계) 정보통신기획평가원(전담), 비영리 법인(설립 중, 주관)",
        "사업 운영 기간": "2019 ~ 계속",
        "사업 신청 기간": "상시",
        "지원 규모(명)": "22년도 선발인원 안내 (예정)",
        "비고": "상시"
      },
      "qualification": {
        "연령": "제한없음",
        "거주지 및 소득": "학생, 청년, 구직자 등 본과정 교육 시작일 기준 민법상 성인 또는 본과정 교육 시작일 기준 고졸 이상의 학력자",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "제한없음",
        "특화 분야": "제한없음",
        "추가 단서 사항": "교육생 선발과정\n상시 모집 > 온라인 신청 > 온라인 테스트 > 본인확인(체크인 미팅) > 1개월 집중 교육 > 에꼴 42 본과정",
        "참여 제한 대상": "-"
      },
      "methods": {
        "신청 절차": "-",
        "심사 및 발표": "-",
        "신청 사이트": "https://innovationacademy.kr/academy/main/view",
        "제출 서류": "-"
      },
      "etc": {
        "기타 유익 정보": "1개월 집중 교육동안 하루 10시간 이상의 강도 높은 코딩을 통해 교육생 역량 증진",
        "주관 기관": "과학기술정보통신부",
        "운영 기관": "(재)이노베이션 아카데미",
        "사업관련 참고 사이트 1": "https://www.42seoul.kr/seoul42/contents/view?contentsNo=13&level=2&menuNo=28",
        "사업관련 참고 사이트 2": "https://www.42seoul.kr/seoul42/contents/view?contentsNo=12&level=1&menuNo=16",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 3,
    "title": "현장연계 미래선도인재양성 지원사업",
    "R-number": "R2023012701501",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023012701501",
      "main_title": "현장연계 미래선도인재양성 지원사업",
      "short_description": "이공계 대학생이 현장 경험을 쌓으며 산업체와 함께 현장 문제 해결을 위한 방안을 도출할 수 있도록, 연구 수행과 대학 공동 온라인 명품강좌 개발, 운영을 지원",
      "summary": {
        "정책 번호": "R2023012701501",
        "정책 분야": "교육분야",
        "지원 내용": "ㅇ 실전문제연구팀 연구과제 지원 : 팀을 구성하여, 산업계 수요조사를 통해 도출한 실전 문제를 중심으로 창의적.도전적 연구과제 수행\nㅇ 실전문제연구팀 지원체계 구축 : 산업체 수요조사 공유 및 연합 팀 구성, 기초‧공통 교육 프로그램 개발.운영, 산업체 현장 실습 등을 통한 역량 제고",
        "사업 운영 기간": "",
        "사업 신청 기간": "2023년 01월  01일 ~ 2023년 03월  07일",
        "지원 규모(명)": "60팀(대학생 연구팀)",
        "비고": "~2023.03.07"
      },
      "qualification": {
        "연령": "제한없음",
        "거주지 및 소득": "ㅇ 주관기관 소속 전임교원으로서 산학연계 및 신진연구인재 육성에 대한 총괄.책임이 가능한 자(3책 5공에는 미포함)",
        "학력": "이공계 대학생",
        "전공": "이공계열",
        "취업 상태": "제한없음",
        "특화 분야": "제한없음",
        "추가 단서 사항": "(팀 구성) 팀장, 팀원, 지도교수 및 산업체 멘토로 구성\n- 팀장 : 대학원생(석ㆍ박사과정생) 또는 박사후연구원\n- 팀원 : 4인 내외의 학부생(이공계 이외 전공 가능)\n* 다학제적 팀 구성 가능 : 다양한 전공의 학생들로 팀을 구성하여 산업체 문제 해결을 위한 창의적 아이디어 도출 및 융합적 문제해결역량 제고\n- 지도교수 : 이공계 소속 전임교원(1인이 최대 2개 팀까지 지도 가능)\n- 산업체 멘토 : 해당 산업체 종사자",
        "참여 제한 대상": "- 참여 제한 등 제재조치 대상자가 아니며, 現ㆍ前 소속 기관 내외부에서 사회적 물의를 일으킨 경우가 없어야 함(지도(참여)교수 동일 적용)\n- 주관연구책임자로서 산학협력 기반 인재 양성 및 연구과제 지원 등을 관리하며, 불가피한 사유(사망, 질병 등) 없이 변경 불가"
      },
      "methods": {
        "신청 절차": "신청서 접수 > 사업계획서 검토 > 사업계획 평가 >최종 검토 및 심의",
        "심사 및 발표": "-",
        "신청 사이트": "http://ernd.nrf.re.kr",
        "제출 서류": "현장연계형 미래선도인재양성지원사업 사업계획서 1부"
      },
      "etc": {
        "기타 유익 정보": "",
        "주관 기관": "과학기술정보통신부",
        "운영 기관": "한국연구재단",
        "사업관련 참고 사이트 1": "https://www.nrf.re.kr/biz/notice/view?biz_not_gubn=guide&menu_no=44&page=1&nts_no=150023&biz_no=494&search_type=NTS_TITLE&search_keyword1=",
        "사업관련 참고 사이트 2": "https://www.nrf.re.kr/index",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 4,
    "title": "양천구 청년 취업 교육 프로그램 지원",
    "R-number": "R2023050912356",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023050912356",
      "main_title": "양천구 청년 취업 교육 프로그램 지원",
      "short_description": "직업교육을 통한 청년 취업연계",
      "summary": {
        "정책 번호": "R2023050912356",
        "정책 분야": "교육분야",
        "지원 내용": "청년 취업연계가 가능한 자격증 취득 및 직업훈련 프로그램 운영",
        "사업 운영 기간": "2023.03월 ~ 12월",
        "사업 신청 기간": "2023년 03월  01일 ~ 2023년 05월  31일",
        "지원 규모(명)": "80명",
        "비고": "2023. 03월 ~ 05월 (프로그램별 상이)"
      },
      "qualification": {
        "연령": "만 19세 ~ 39세",
        "거주지 및 소득": "취업을 준비하는 청년",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "제한없음",
        "특화 분야": "제한없음",
        "추가 단서 사항": "-",
        "참여 제한 대상": "-"
      },
      "methods": {
        "신청 절차": "양천구 게시판 > 청년 취업연계 프로그램 검색 > 선택 후 프로그램 별 담당자 문의",
        "심사 및 발표": "개별안내",
        "신청 사이트": "https://www.youth.go.kr/index.do",
        "제출 서류": "온라인 신청서, 자기소개서 등"
      },
      "etc": {
        "기타 유익 정보": "-",
        "주관 기관": "양천구청 청년일자리지원센터",
        "운영 기관": "양천구청 청년정책과",
        "사업관련 참고 사이트 1": "",
        "사업관련 참고 사이트 2": "https://www.youth.go.kr/index.do",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 5,
    "title": "창조적 예비청년창업가(로컬 크리에이터)",
    "R-number": "R2023050912499",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023050912499",
      "main_title": "창조적 예비청년창업가(로컬 크리에이터)",
      "short_description": "골목상권에서 지역가치를 차별화된 콘텐츠로 구현하며 매력적인 도시문화를 이끌어낼 수 있는 로컬크리에이터를 양성",
      "summary": {
        "정책 번호": "R2023050912499",
        "정책 분야": "일자리분야",
        "지원 내용": "교육지원(5개월)",
        "사업 운영 기간": "2022.03.01~2023.12.31",
        "사업 신청 기간": "미정",
        "지원 규모(명)": "10팀내외",
        "비고": "추후공지"
      },
      "qualification": {
        "연령": "만 19세 ~ 39세",
        "거주지 및 소득": "공고일기준 서울시 거주 및 19시이상 39세미만\n로컬브랜드상권 2기 대상지에 창업을 희망하는자",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "(예비)창업자",
        "특화 분야": "제한없음 (예비창업자)",
        "추가 단서 사항": "-",
        "참여 제한 대상": "-"
      },
      "methods": {
        "신청 절차": "1. 서류 : 선정 규모의 2배수 내외를 발표평가 대상자로 선발 2. 발표평가 : 10분 발표, 10분 질의응답",
        "심사 및 발표": "추후공지",
        "신청 사이트": "추후공지",
        "제출 서류": "추후공지"
      },
      "etc": {
        "기타 유익 정보": "-",
        "주관 기관": "서울신용보증재단",
        "운영 기관": "주관기관과동일",
        "사업관련 참고 사이트 1": "",
        "사업관련 참고 사이트 2": "",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 6,
    "title": "제대군인 직업능력개발교육비",
    "R-number": "R2023042612201",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023042612201",
      "main_title": "제대군인 직업능력개발교육비",
      "short_description": "전역예정자의 직업능력 개발교육비 지원",
      "summary": {
        "정책 번호": "R2023042612201",
        "정책 분야": "교육분야",
        "지원 내용": "중•장기 복무 전역(예정)자에 최대 150만원 한도의 직업능력개발교육비 지원",
        "사업 운영 기간": "연중",
        "사업 신청 기간": "상시",
        "지원 규모(명)": "-",
        "비고": "상시"
      },
      "qualification": {
        "연령": "제한없음",
        "거주지 및 소득": "교육시작일 및 직업교육비 신청일 현재 중・장기복무 제대(예정)군인으로 주소지 관할 보훈(지)청 또는 Vnet(제대군인지원센터)에 등록된 사람, vnet에 등록된 회원으로 전직 기본교육을 이수한 사람,  vnet 및 보훈(지)청에 등록된 회원으로 전역 후 3년 이내 미 취・창업자 또는 비정규직 취업자(근로계약기간 2년을 초과하지 않을 것)",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "미취업자",
        "특화 분야": "군인",
        "추가 단서 사항": "수강료의 국비지원 비율 80%, 자기부담율 20%",
        "참여 제한 대상": "전역 과정에 대해서는 지원하지 아니함(이중 지원 금지)"
      },
      "methods": {
        "신청 절차": "제대군인지원센터에 유선으로 신청",
        "심사 및 발표": "지원센터의 담당 상담사와 상담 후 지원 대상으로 결정",
        "신청 사이트": "-",
        "제출 서류": "직업능력개발교육비 지원신청서(교육 시작 전), 교육과정 수료 후 14일 이내에 교육 수료증 또는 교육 수료 확인서(교육 수료 후)"
      },
      "etc": {
        "기타 유익 정보": "지원센터의 담당 상담사와 상담 후 지원 대상으로 결정되면 수강등록 후 교육 시작일로부터 7일 이내에 신청 서류를 제출할 것 단, 단기과정(1~7일)의 경우 교육 시작일까지 사전상담을 실시한 경우에 한해 적용",
        "주관 기관": "국가보훈처",
        "운영 기관": "국가보훈처 제대군인지원센터",
        "사업관련 참고 사이트 1": "https://www.vnet.go.kr/gud/GudCv004.do",
        "사업관련 참고 사이트 2": "-",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 7,
    "title": "고양청년 창업 재정지원 프로그램",
    "R-number": "R2023060213115",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023060213115",
      "main_title": "고양청년 창업 재정지원 프로그램",
      "short_description": "참신한 아이디어와 사업성을 가진 고양시 청년들의 창업 성공 가능성을 높이기 위한 실효성 있는 시책 추진",
      "summary": {
        "정책 번호": "R2023060213115",
        "정책 분야": "일자리분야",
        "지원 내용": "청년 창업자에게 무담보 신용보증, 최대 5천만 원 대출",
        "사업 운영 기간": "자금 소진 시 까지",
        "사업 신청 기간": "상시",
        "지원 규모(명)": "예산 범위 내",
        "비고": "상시"
      },
      "qualification": {
        "연령": "만 18세 ~ 39세",
        "거주지 및 소득": "고양시에 사업자 등록 및 매출이 발생한 청년 창업자(실제 매출이 발생하는지 실사 진행 후 대출 실행)",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "제한없음",
        "특화 분야": "제한없음",
        "추가 단서 사항": "개인 신용도에 따라 최대 보증금액 및 이율 상이",
        "참여 제한 대상": "타지역 또는 창업후 5년 이상"
      },
      "methods": {
        "신청 절차": "경기신용보증재단 고양지점 방문상담\n경기신용보증재단 고양지점 - 1577-5900\n(고양시 일산서구 중앙로 1442, 5층)",
        "심사 및 발표": "개별 안내",
        "신청 사이트": "https://www.goyang.go.kr/www/www03/www03_8/www03_8_14/www03_8_14_tab2.jsp",
        "제출 서류": "신분증 및 사업자 등록증"
      },
      "etc": {
        "기타 유익 정보": "-",
        "주관 기관": "고양시 청년담당관",
        "운영 기관": "경기신용보증재단 고양지점",
        "사업관련 참고 사이트 1": "https://goyangjobcafe.kr/청년정책/청년-재정지원",
        "사업관련 참고 사이트 2": "https://www.goyang.go.kr/www/index.do",
        "첨부파일": ""
      }
    }
  },
  {
    "YP": 8,
    "title": "엔젤공방거리 조성",
    "R-number": "R2023050912244",
    "contents": {
      "url": "https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&bizId=R2023050912244",
      "main_title": "엔젤공방거리 조성",
      "short_description": "성내도서관 주변 변종업소로 어둡던 골목을 정비하고 사회적경제 방식의 일자리창출로 강동구 사회적경제 생태계 확대에 기여",
      "summary": {
        "정책 번호": "R2023050912244",
        "정책 분야": "일자리분야",
        "지원 내용": "보증금, 임차료(입점 첫해에 한해 50퍼센트 지원), 기본 인테리어 시설\n홍보 및 사업지원 : 수요자 중심의 사업지원체계 및 성장단계별 맞춤형 지원",
        "사업 운영 기간": "상시",
        "사업 신청 기간": "상시",
        "지원 규모(명)": "-",
        "비고": "상시"
      },
      "qualification": {
        "연령": "만 19세 ~ 39세",
        "거주지 및 소득": "만 19세 이상 ~ 만 39세 이하 창업희망자",
        "학력": "제한없음",
        "전공": "제한없음",
        "취업 상태": "제한없음",
        "특화 분야": "제한없음",
        "추가 단서 사항": "-",
        "참여 제한 대상": "-"
      },
      "methods": {
        "신청 절차": "모집방법: 강동구청 홈페이지 고시/공고 게재\n신청접수 및 절차: 기타 자세한 사항은 강동구청 사회적경제과(02-3425-5822)로 문의",
        "심사 및 발표": "- 서류심사\n- 면접심사\n- 입주",
        "신청 사이트": "-",
        "제출 서류": "사업계획서 및 구비서류"
      },
      "etc": {
        "기타 유익 정보": "-",
        "주관 기관": "강동구청 기획경제국 일자리정책과",
        "운영 기관": "-",
        "사업관련 참고 사이트 1": "http://www.gdangelhub.or.kr",
        "사업관련 참고 사이트 2": "https://www.gangdong.go.kr",
        "첨부파일": ""
      }
    }
  }
]

# %%
contents=[]

for data in Pdata:
    # data에서 실제로 필요한 정보만 추출
    content = f"제목: {data['title']}\n지원내용: {data['contents']['short_description']}\n"
    methods = data['contents']['methods']
    for key, value in methods.items():
        if value != '-':
            content += f'{key}: {value}\n'
    qualification = data['contents']['qualification']
    for key, value in qualification.items():
        if value != '-':
            content += f'{key}: {value}\n'
    contents.append(content)
print(contents[4])
# Out:
# 제목: 양천구 청년 취업 교육 프로그램 지원
# 지원내용: 직업교육을 통한 청년 취업연계
# 신청 절차: 양천구 게시판 > 청년 취업연계 프로그램 검색 > 선택 후 프로그램 별 담당자 문의
# 심사 및 발표: 개별안내
# 신청 사이트: https://www.youth.go.kr/index.do
# 제출 서류: 온라인 신청서, 자기소개서 등
# 연령: 만 19세 ~ 39세
# 거주지 및 소득: 취업을 준비하는 청년
# 학력: 제한없음
# 전공: 제한없음
# 취업 상태: 제한없음
# 특화 분야: 제한없음

# %%
import os
import openai

#input your api
openai.api_key = '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'

# %%
system_prompt_1 = """너는 질문생성의 전문가야.
너의 할 일은 대한민국 청년 정책에 대한 정보를 받으면, 그 정보를 바탕으로 답을 추론해낼수 있는 질문들을 만드는거야. 
정책정보는 항목 : 데이터 의 형태로 알려줄거야
항목은 두개 이상 사용해서, 반드시 하나의 질문만 만들어줘
"""

user_prompt_1 = """
아래는 예시야.

예시 1:
정책 정보:
제목: 수원시 청년 주거 대출 프로그램
지원내용: 수원시에 거주하는 청년층이 받을 수 있는 대출 프로그램
연령: 만 19세 ~ 34세
거주지 및 소득: 수원시 거주, 중소기업에 재직 중인 청년
학력: 제한없음
전공: 제한없음
취업 상태: 중소기업에 1년 이상 재직 중
특화 분야: 제한없음

생성해야할 질문 예시:
Q : 수원시에 거주 중인 청년이고 중소기업에 1년 정도 다니고 있는 청년입니다. 제가 받을 수 있는 주거 관련 정책 프로그램이 있나요? 

다음 주어지는 정책 정보를 이용해 질문을 한개만 만들어줘
정책 정보: {passage}
"""

# %%
system_prompt_2 = """
입력된 질문에 대해 비슷한 맥락을 갖지만 다른 형식의 질문을 만들어줘.
"""

user_prompt_2 = """
you have to make 3 different questions for the input question. Each sentence has the same meaning, but it should be a different sentence.
Please make questions with very differnet format like below.

This is example:
Q1 : 서울시 강남구에 거주 중인 취준생인데, 코딩 관련 교육 프로그램에 대해 알려주세요. 

different Questions:
Q1-1 : 나 강남사는데 정책추천해줘라
Q1-2 : 취준생인데 코딩배워보고싶어. 관련 정책 있어?
Q1-3 : 강남에 취준생을 대상으로하는 코딩 교육 프로그램 있니?
 

input : {passage}
"""

# %%
system_prompt_1 = """You are an expert in question generation.
Your task is to make questions that, when you receive information about Korea's youth policy, you can infer the answers based on that information.
Policy information will be provided in the form of scheme : data
Make sure to use at least two scheme.

Example : 

예시 1:
정책 정보:
제목: 현장연계 미래선도인재양성 지원사업
지원내용: 이공계 대학생이 현장 경험을 쌓으며 산업체와 함께 현장 문제 해결을 위한 방안을 도출할 수 있도록, 연구 수행과 대학 공동 온라인 명품강좌 개발, 운영을 지원
신청 절차: 신청서 접수 > 사업계획서 검토 > 사업계획 평가 >최종 검토 및 심의
신청 사이트: http://ernd.nrf.re.kr
제출 서류: 현장연계형 미래선도인재양성지원사업 사업계획서 1부
연령: 제한없음
거주지 및 소득: ㅇ 주관기관 소속 전임교원으로서 산학연계 및 신진연구인재 육성에 대한 총괄.책임이 가능한 자(3책 5공에는 미포함)
학력: 이공계 대학생
전공: 이공계열
취업 상태: 제한없음
특화 분야: 제한없음
추가 단서 사항: (팀 구성) 팀장, 팀원, 지도교수 및 산업체 멘토로 구성
- 팀장 : 대학원생(석ㆍ박사과정생) 또는 박사후연구원
- 팀원 : 4인 내외의 학부생(이공계 이외 전공 가능)
* 다학제적 팀 구성 가능 : 다양한 전공의 학생들로 팀을 구성하여 산업체 문제 해결을 위한 창의적 아이디어 도출 및 융합적 문제해결역량 제고
- 지도교수 : 이공계 소속 전임교원(1인이 최대 2개 팀까지 지도 가능)
- 산업체 멘토 : 해당 산업체 종사자
참여 제한 대상: - 참여 제한 등 제재조치 대상자가 아니며, 現ㆍ前 소속 기관 내외부에서 사회적 물의를 일으킨 경우가 없어야 함(지도(참여)교수 동일 적용)
- 주관연구책임자로서 산학협력 기반 인재 양성 및 연구과제 지원 등을 관리하며, 불가피한 사유(사망, 질병 등) 없이 변경 불가

Example for output :
Q : 20대 이공계열 대학생이 받을수있는 청년정책이 있을까요?
Q : 

"""

user_prompt_1 = """
Make one question using the policy information given below
정책 정보: {passage}
"""

# %%
system_prompt_2 = """
You are an excellent question generator.
Please create a similar context for the input question but a different format.

You have to make 3 different questions for the input question. Each sentence has the same meaning, but it should be a different sentence.
Please make questions with differnet format and information like below.

Generated Question Format Example:
First generated question: Only include site, user state, specific policy.
Second generated question: Only include age, sex, site.
Third generated question: Only include age, site.

Example:
Input Question : 서울시 강남구에 거주 중인 만 23세 남성 취준생인데, 코딩 관련 교육 프로그램에 대해 알려주세요. 

different Questions:
Q1-1 : 강남사는데 코딩관련 정책추천해줘라
Q1-2 : 나 23세 남성이고 강남 사는데, 내가 받을 수 있는 정책 혜택을 알려줘.
Q1-3 : 23세 강남 거주중인 청년인데 혜택을 알려줄래?

"""

user_prompt_2 = """Input : {passage}
"""

# %%
def generate_question_1(passage):
    messages =[
        {'role':'system', 'content':system_prompt_1},
        {'role':'user', 'content':user_prompt_1.format(passage=passage)}
    ]
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0,
        max_tokens=1000,
        top_p=1.0,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response['choices'][0]['message']['content']

def generate_question_2(passage):
    messages =[
        {'role':'system', 'content':system_prompt_2},
        {'role':'user', 'content':user_prompt_2.format(passage=passage)}
    ]
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0.7,
        max_tokens=1000,
        top_p=1.0,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response['choices'][0]['message']['content']

# %%
user_prompt_1 = """
요약해줘.
정책 정보: {passage}
"""

user_prompt_2 = """
위 정책정보로 정답을 도출해낼수있는 질문을 5개 만들어줘
질문은 간결하게 3개, 복잡하게 2개 만들어줘
예시 : 
Q1 : 강남사는데 코딩관련 정책추천해줘라
Q2 : 나 23세 남성이고 강남 사는데, 내가 받을 수 있는 정책 혜택을 알려줘.
Q3 : 23세 강남 거주중인 청년인데 혜택을 알려줄래?
정책 정보: {passage}
"""

def generate_question_1(passage):
    messages =[
        {'role':'system', 'content':'청년들을 돕기위한 정책정보를 요약해주세요'},
        {'role':'user', 'content':user_prompt_1.format(passage=passage)}
    ]
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0,
        max_tokens=1000,
        top_p=1.0,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response['choices'][0]['message']['content']

def generate_question_2(passage):
    messages =[
        {'role':'system', 'content':'다음 정보를 이용하여 질문을 만들어주세요.'},
        {'role':'user', 'content':user_prompt_2.format(passage=passage)}
    ]
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0,
        max_tokens=1000,
        top_p=1.0,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response['choices'][0]['message']['content']

for content in contents[7:]:
    #generated_question = generate_question_1(content)
    print()
    #print(generated_question)
    #print()
    print(generate_question_2(content))
# Out:
# 간결한 질문:
# Q1: 고양시 청년 창업자를 위한 재정지원 프로그램은 어떤 내용을 포함하고 있나요?
# Q2: 고양시 청년 창업자를 위한 재정지원 프로그램에 신청하기 위해 필요한 서류는 무엇인가요?
# Q3: 고양시 청년 창업자를 위한 재정지원 프로그램에 참여하기 위한 연령 제한은 어떻게 되나요?
#
# 복잡한 질문:
# Q4: 고양시에 거주하고 있는 25세 청년이고, 사업자 등록 및 매출이 발생한 상태인데, 개인 신용도에 따라 최대 보증금액과 이율이 어떻게 달라지는지 알려주세요.
# Q5: 고양시 일산서구에 거주하고 있는 30세 청년이고, 고양시 외에서 창업한지 3년이 지났습니다. 이 청년은 고양시 청년 창업 재정지원 프로그램에 참여할 수 있을까요?
#
# 간단한 질문:
# Q1: 강동구 사회적경제 생태계 확대를 위한 엔젤공방거리 조성 정책은 어떤 내용을 포함하고 있나요?
# Q2: 엔젤공방거리 조성 정책은 어떤 방식으로 신청하고 절차가 진행되나요?
# Q3: 엔젤공방거리 조성 정책은 어떤 연령대와 거주지 조건을 만족해야 신청할 수 있나요?
#
# 복잡한 질문:
# Q4: 엔젤공방거리 조성 정책의 신청 절차에서 서류심사, 면접심사, 입주까지의 과정에서 각각 어떤 기준으로 심사가 이루어지나요?
# Q5: 엔젤공방거리 조성 정책의 신청자는 학력, 전공, 취업 상태 등에 대한 제한이 있는지 알려주세요.

# %%
for content in contents[4:]:
    generated_question = generate_question_1(content)
    print()
    print(generated_question)
    print()
    print(generate_question_2(generated_question))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/zino/Desktop/ChatPub/data_generation_gpt-3.5.ipynb Cell 12 line 2
#       <a href='vscode-notebook-cell:/Users/zino/Desktop/ChatPub/data_generation_gpt-3.5.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> for content in contents[4:]:
# ----> <a href='vscode-notebook-cell:/Users/zino/Desktop/ChatPub/data_generation_gpt-3.5.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a>     generated_question = generate_question_1(content)
#       <a href='vscode-notebook-cell:/Users/zino/Desktop/ChatPub/data_generation_gpt-3.5.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     print()
#       <a href='vscode-notebook-cell:/Users/zino/Desktop/ChatPub/data_generation_gpt-3.5.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>     print(generated_question)
#
# /Users/zino/Desktop/ChatPub/data_generation_gpt-3.5.ipynb Cell 12 line 3
# ...

# %%
user_prompt_1 = """
청년정책에 대해 알려주는 챗봇을 만들고있어. 학습에 쓰일 질문을 만들어야해.
다양한 각도에서 질문을 5개 만들어줘.

정책정보는 각각 항목 : 데이터 로 이루어져 있어.

예를들면 
제목: 양천구 청년 취업 교육 프로그램 지원
지원내용: 직업교육을 통한 청년 취업연계
신청 절차: 양천구 게시판 > 청년 취업연계 프로그램 검색 > 선택 후 프로그램 별 담당자 문의
심사 및 발표: 개별안내
신청 사이트: https://www.youth.go.kr/index.do
제출 서류: 온라인 신청서, 자기소개서 등
연령: 만 19세 ~ 39세
거주지 및 소득: 취업을 준비하는 청년
학력: 제한없음
전공: 제한없음
취업 상태: 제한없음
특화 분야: 제한없음

정책 정보: {passage}
이 정보를 이용하여 질문을 만들어줘. 

"""

def generate_question_1(passage):
    messages =[
        {'role':'system', 'content':'질문을 만들어주세요'},
        {'role':'user', 'content':user_prompt_1.format(passage=passage)}
    ]
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0,
        max_tokens=1000,
        top_p=1.0,
        frequency_penalty=0,
        presence_penalty=0
    )

    return response['choices'][0]['message']['content']

for content in contents[4:]:
    #generated_question = generate_question_1(content)
    print()
    #print(generated_question)
    #print()
    print(generate_question_1(content))
# Out:
# 1. 양천구 청년 취업 교육 프로그램 지원은 어떤 내용으로 이루어져 있나요?
# 2. 양천구 청년 취업 교육 프로그램을 신청하려면 어떤 절차를 거쳐야 하나요?
# 3. 양천구 청년 취업 교육 프로그램 신청 후 심사 및 발표는 어떻게 이루어지나요?
# 4. 양천구 청년 취업 교육 프로그램 신청을 위해 필요한 서류는 무엇인가요?
# 5. 양천구 청년 취업 교육 프로그램은 어떤 연령대와 학력, 전공, 취업 상태에 제한이 있나요?
#
# 1. 양천구 청년 취업 교육 프로그램 지원의 신청 절차는 어떻게 되나요?
# 2. 창조적 예비청년창업가(로컬 크리에이터) 정책의 신청 사이트는 어디인가요?
# 3. 양천구 청년 취업 교육 프로그램 지원의 연령 제한은 어떻게 되나요?
# 4. 창조적 예비청년창업가(로컬 크리에이터) 정책의 신청 서류는 어떤 것들이 필요한가요?
# 5. 양천구 청년 취업 교육 프로그램 지원의 특화 분야에는 어떤 것들이 포함되나요?
#
# 1. 양천구 청년 취업 교육 프로그램 지원의 신청 절차는 어떻게 되나요?
# 2. 제대군인 직업능력개발교육비 지원의 신청은 어떻게 하면 되나요?
# 3. 청년 취업연계 프로그램의 연령 제한은 있나요?
# 4. 제대군인 직업능력개발교육비 지원의 지원 대상은 어떻게 결정되나요?
# 5. 청년 취업 교육 프로그램 지원의 심사 및 발표 방식은 어떻게 이루어지나요?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/zino/Desktop/ChatPub/data_generation_gpt-3.5.ipynb Cell 13 line 4
# ...
